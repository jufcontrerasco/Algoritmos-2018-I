# %%
from itertools import permutations
n = int(input())
permu = list(permutations(range(1,n+1)))
sum = 0
avg =0
for k in range(0,len(permu)):
    pre = 0
    comp = 0
    swap = 0
    i = 1
    aux = list(permu[k])
    preguntas =[]
    print("Permutacion de entrada: "+str(aux))
    while i < len(aux):
        x = aux[i]
        j = i-1
        pre = pre+1
        comp = comp+1
        while j > -1 and aux[j] > x:
            aux[j+1] = aux[j]
            swap = swap + 1
            aux[j] = x
            j = j-1
            if j >= -1:
                pre= pre+1
            if j >= 0:
                comp= comp+1
        preguntas.append(pre)
        pre = 0
        if len(preguntas) == len(aux)-1:
            print("Numero de preguntas: "+str(preguntas))
        i = i+1
        """print( "Cambio: "+str(aux[:]) )"""
    for i in range(0,len(preguntas)):
        sum = sum + preguntas[i]
    print("Comparaciones: "+str(comp))
    print("Swaps: "+str(swap))
    print ("Lista ordenada: %s" % aux)
    print("Numero de pasos: "+str(2*n-1+3*(sum))+"\n")
    avg = avg+(2*n-1+3*(sum))
    preguntas = []
    sum = 0
print("Numero promedio de pasos: "+str(avg/len(permu)))
# Out:
# 4
# Permutacion de entrada: [1, 2, 3, 4]
# Numero de preguntas: [1, 1, 1]
# Comparaciones: 3
# Swaps: 0
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 16
#
# Permutacion de entrada: [1, 2, 4, 3]
# Numero de preguntas: [1, 1, 2]
# Comparaciones: 4
# Swaps: 1
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 19
#
# Permutacion de entrada: [1, 3, 2, 4]
# Numero de preguntas: [1, 2, 1]
# Comparaciones: 4
# Swaps: 1
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 19
#
# Permutacion de entrada: [1, 3, 4, 2]
# Numero de preguntas: [1, 1, 3]
# Comparaciones: 5
# Swaps: 2
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 22
#
# Permutacion de entrada: [1, 4, 2, 3]
# Numero de preguntas: [1, 2, 2]
# Comparaciones: 5
# Swaps: 2
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 22
#
# Permutacion de entrada: [1, 4, 3, 2]
# Numero de preguntas: [1, 2, 3]
# Comparaciones: 6
# Swaps: 3
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 25
#
# Permutacion de entrada: [2, 1, 3, 4]
# Numero de preguntas: [2, 1, 1]
# Comparaciones: 3
# Swaps: 1
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 19
#
# Permutacion de entrada: [2, 1, 4, 3]
# Numero de preguntas: [2, 1, 2]
# Comparaciones: 4
# Swaps: 2
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 22
#
# Permutacion de entrada: [2, 3, 1, 4]
# Numero de preguntas: [1, 3, 1]
# Comparaciones: 4
# Swaps: 2
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 22
#
# Permutacion de entrada: [2, 3, 4, 1]
# Numero de preguntas: [1, 1, 4]
# Comparaciones: 5
# Swaps: 3
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 25
#
# Permutacion de entrada: [2, 4, 1, 3]
# Numero de preguntas: [1, 3, 2]
# Comparaciones: 5
# Swaps: 3
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 25
#
# Permutacion de entrada: [2, 4, 3, 1]
# Numero de preguntas: [1, 2, 4]
# Comparaciones: 6
# Swaps: 4
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 28
#
# Permutacion de entrada: [3, 1, 2, 4]
# Numero de preguntas: [2, 2, 1]
# Comparaciones: 4
# Swaps: 2
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 22
#
# Permutacion de entrada: [3, 1, 4, 2]
# Numero de preguntas: [2, 1, 3]
# Comparaciones: 5
# Swaps: 3
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 25
#
# Permutacion de entrada: [3, 2, 1, 4]
# Numero de preguntas: [2, 3, 1]
# Comparaciones: 4
# Swaps: 3
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 25
#
# Permutacion de entrada: [3, 2, 4, 1]
# Numero de preguntas: [2, 1, 4]
# Comparaciones: 5
# Swaps: 4
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 28
#
# Permutacion de entrada: [3, 4, 1, 2]
# Numero de preguntas: [1, 3, 3]
# Comparaciones: 6
# Swaps: 4
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 28
#
# Permutacion de entrada: [3, 4, 2, 1]
# Numero de preguntas: [1, 3, 4]
# Comparaciones: 6
# Swaps: 5
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 31
#
# Permutacion de entrada: [4, 1, 2, 3]
# Numero de preguntas: [2, 2, 2]
# Comparaciones: 5
# Swaps: 3
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 25
#
# Permutacion de entrada: [4, 1, 3, 2]
# Numero de preguntas: [2, 2, 3]
# Comparaciones: 6
# Swaps: 4
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 28
#
# Permutacion de entrada: [4, 2, 1, 3]
# Numero de preguntas: [2, 3, 2]
# Comparaciones: 5
# Swaps: 4
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 28
#
# Permutacion de entrada: [4, 2, 3, 1]
# Numero de preguntas: [2, 2, 4]
# Comparaciones: 6
# Swaps: 5
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 31
#
# Permutacion de entrada: [4, 3, 1, 2]
# Numero de preguntas: [2, 3, 3]
# Comparaciones: 6
# Swaps: 5
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 31
#
# Permutacion de entrada: [4, 3, 2, 1]
# Numero de preguntas: [2, 3, 4]
# Comparaciones: 6
# Swaps: 6
# Lista ordenada: [1, 2, 3, 4]
# Numero de pasos: 34
#
# Numero promedio de pasos: 25.0
