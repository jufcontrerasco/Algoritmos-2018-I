# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt

f = int(input("Hasta que tamaño de matriz nxn desea usar?: "))
a = np.full((f, f),1)
b = np.full((f, f),2)
tiempos = []
r = []
j = []
for k in range (0,10):
    for i in range (1, f+1):
        tiempo_inicio = time()
        a = np.full((i, i), 1)
        b = np.full((i, i), 2)
        print(np.matmul(a, b))
        tiempo_final = time()
        tiempo_ejecucion = tiempo_final-tiempo_inicio
        if k ==0:
            tiempos.append(tiempo_ejecucion)
        else:
            tiempos[i-1] = tiempos[i-1]+tiempo_ejecucion


for i in range(f):
    r.insert(0,tiempos[i]/10)
    j.append(i+1)

print(r)

plt.plot(j,r)
plt.ylabel('Tiempo de ejecución promedio')
plt.xlabel("Tamaño de matriz")
plt.axis([1, f, 0, max(r)])
plt.show()
# Out:
# Hasta que tamaño de matriz nxn desea usar?: 15
# [[2]]
# [[4 4]
#  [4 4]]
# [[6 6 6]
#  [6 6 6]
#  [6 6 6]]
# [[8 8 8 8]
#  [8 8 8 8]
#  [8 8 8 8]
#  [8 8 8 8]]
# [[10 10 10 10 10]
#  [10 10 10 10 10]
#  [10 10 10 10 10]
#  [10 10 10 10 10]
#  [10 10 10 10 10]]
# [[12 12 12 12 12 12]
#  [12 12 12 12 12 12]
#  [12 12 12 12 12 12]
#  [12 12 12 12 12 12]
#  [12 12 12 12 12 12]
#  [12 12 12 12 12 12]]
# [[14 14 14 14 14 14 14]
#  [14 14 14 14 14 14 14]
#  [14 14 14 14 14 14 14]
#  [14 14 14 14 14 14 14]
#  [14 14 14 14 14 14 14]
#  [14 14 14 14 14 14 14]
#  [14 14 14 14 14 14 14]]
# [[16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]
#  [16 16 16 16 16 16 16 16]]
# [[18 18 18 18 18 18 18 18 18]
#  [18 18 18 18 18 18 18 18 18]
#  [18 18 18 18 18 18 18 18 18]
#  [18 18 18 18 18 18 18 18 18]
#  [18 18 18 18 18 18 18 18 18]
# ...
